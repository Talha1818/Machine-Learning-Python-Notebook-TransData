# %% [markdown]
# <a href="https://colab.research.google.com/github/Talha1818/Machine-Learning-Python-Notebooks/blob/master/Check_Frequency_of_Documents_TrasnData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import glob
import os
import pandas as pd
import numpy as np
from tqdm.auto import tqdm
import re

# %%
folder_path = "/content/drive/MyDrive/Annotation Folder/TrainingCSVFiles"
file_pattern = "*.csv"

csv_files__ = glob.glob(os.path.join(folder_path, file_pattern))
PACKAGE_NAME = [i.split("/")[-1].split(".")[0] for i in csv_files__]
print("Total Packages: ", len(PACKAGE_NAME))
# Out:
# Total Packages:  882

# %%
dataframe = []
for i in tqdm(csv_files__):
  dataframe.append(pd.read_csv(i))
# Out:
#   0%|          | 0/882 [00:00<?, ?it/s]

# %%
df = pd.concat(dataframe, axis = 0)
df.shape
# Out:
# (82296, 4)

# %%
df.head()
# Out:
#    page#      package_name                                               text  \
# 0    1.0  612007_NJ_CAMDEN  zp wo o\ngD ong 8 8 n xmwor\n3 5 ee S S ee nN\...
# 1    2.0  612007_NJ_CAMDEN  |\n[gem a CASHIER'S CHECK 6780001482\n| Remite...
# 2    3.0  612007_NJ_CAMDEN  City Abstract, LLC ALTA Buyer's Final Settleme...
# 3    4.0  612007_NJ_CAMDEN  Po Description\nTile Platform Fee (TMP) to Ciy...
# 4    5.0  612007_NJ_CAMDEN  City Abstract, LLC ALTA Seller's Settlement St...
#
#   token
# 0    15
# 1    15
# 2    11
# 3    11
# 4    13

# %%
# dataset = dataset[['text', 'token']]
df = df[~(df['text']=='')]
df = df[~(df['token']=='')]
df = df[~(df['token']==' ')]
df = df[df['text'].notna()]
df = df[df['token'].notna()]

# %%
df.head()
# Out:
#    page#      package_name                                               text  \
# 0    1.0  612007_NJ_CAMDEN  zp wo o\ngD ong 8 8 n xmwor\n3 5 ee S S ee nN\...
# 1    2.0  612007_NJ_CAMDEN  |\n[gem a CASHIER'S CHECK 6780001482\n| Remite...
# 2    3.0  612007_NJ_CAMDEN  City Abstract, LLC ALTA Buyer's Final Settleme...
# 3    4.0  612007_NJ_CAMDEN  Po Description\nTile Platform Fee (TMP) to Ciy...
# 4    5.0  612007_NJ_CAMDEN  City Abstract, LLC ALTA Seller's Settlement St...
#
#   token
# 0    15
# 1    15
# 2    11
# 3    11
# 4    13

# %%
df.shape
# Out:
# (81393, 4)

# %%
import re
import pandas as pd
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
import re
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Define regex patterns
punct_pattern = r'[^\w\s]'
num_pattern = r'\d+'
special_pattern = r'[^A-Za-z0-9\s]'

# Define cleaning function
def clean_text(text):
    text = re.sub(r'\\n|\n', ' ', text)
    # remove links
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r'\x00|\\x00', '', text)
    # Convert to lowercase
    text = text.lower()
    # Remove punctuation
    text = re.sub(punct_pattern, '', text)
    # Remove integers
    text = re.sub(num_pattern, '', text)
    # Remove special characters
    text = re.sub(special_pattern, '', text)
    # Remove extra whitespace
    text = re.sub('\s+', ' ', text).strip()
    # Remove nextline
    text = re.sub(r'\n', ' ', text)
    # Remove words with length 1
    text = ' '.join(word for word in text.split() if len(word) > 2)
    # Remove stop words
    stop_words = set(stopwords.words('english'))
    text = ' '.join(word for word in text.split() if word not in stop_words)
    return text

# Apply cleaning function to text feature
df['clean_text'] = df['text'].apply(clean_text)

# %%
df.head()
# Out:
#    page#      package_name                                               text  \
# 0    1.0  612007_NJ_CAMDEN  zp wo o\ngD ong 8 8 n xmwor\n3 5 ee S S ee nN\...
# 1    2.0  612007_NJ_CAMDEN  |\n[gem a CASHIER'S CHECK 6780001482\n| Remite...
# 2    3.0  612007_NJ_CAMDEN  City Abstract, LLC ALTA Buyer's Final Settleme...
# 3    4.0  612007_NJ_CAMDEN  Po Description\nTile Platform Fee (TMP) to Ciy...
# 4    5.0  612007_NJ_CAMDEN  City Abstract, LLC ALTA Seller's Settlement St...
#
#   token                                         clean_text
# 0    15  ong xmwor nnupoo sko uuuuuuu aneaf uuuuu tssar...
# 1    15  gem cashiers check remiter salvador carrasco o...
# 2    11  city abstract llc alta buyers final settlement...
# 3    11  description tile platform fee tmp ciyabstrack ...
# 4    13  city abstract llc alta sellers settlement stat...

# %%
df.to_csv("/content/drive/MyDrive/Annotation Folder/Final_Text_Dataset_27_March_2023.csv", index=False)

# %% [markdown]
# # **Store Frequency of Documents**

# %%
df = pd.read_csv("/content/drive/MyDrive/Annotation Folder/Final_Text_Dataset_27_March_2023.csv")
df.head()
# Out:
#    page#      package_name                                               text  \
# 0    1.0  612007_NJ_CAMDEN  zp wo o\ngD ong 8 8 n xmwor\n3 5 ee S S ee nN\...
# 1    2.0  612007_NJ_CAMDEN  |\n[gem a CASHIER'S CHECK 6780001482\n| Remite...
# 2    3.0  612007_NJ_CAMDEN  City Abstract, LLC ALTA Buyer's Final Settleme...
# 3    4.0  612007_NJ_CAMDEN  Po Description\nTile Platform Fee (TMP) to Ciy...
# 4    5.0  612007_NJ_CAMDEN  City Abstract, LLC ALTA Seller's Settlement St...
#
#    token                                         clean_text
# 0   15.0  ong xmwor nnupoo sko uuuuuuu aneaf uuuuu tssar...
# 1   15.0  gem cashiers check remiter salvador carrasco o...
# 2   11.0  city abstract llc alta buyers final settlement...
# 3   11.0  description tile platform fee tmp ciyabstrack ...
# 4   13.0  city abstract llc alta sellers settlement stat...

# %%
df['token'] = df['token'].astype(int)

# %%
freq = df['token'].value_counts().to_frame().reset_index().rename(columns={'index':'token','token':'Frequency_Documents'})
freq.head()
# Out:
#    token  Frequency_Documents
# 0     15                 6014
# 1     14                 5180
# 2     28                 4230
# 3     30                 4120
# 4     40                 4006

# %%
df_token = pd.read_csv("/content/drive/MyDrive/Annotation Folder/lender_docs_token.csv")
df_token.head()
# Out:
#   Keys  Token               Meaning Classification
# 0   CS    0.0           Cover Sheet    Lender Docs
# 1  MUC    1.0  MARKED UP COMMITMENT            NaN
# 2   DC    2.0             DEED COPY            NaN
# 3  AOT    3.0          AFF OF TITLE            NaN
# 4   IA    4.0  ID AFFIDAVIT (Buyer)            NaN

# %%
def get_token_meaning(df, target_name = 'target'):
  token_name = []
  for i in df[target_name]:
    try:
      token_name.append(df_token[df_token['Token']==i]['Meaning'].values[0])
    except:
      token_name.append('')
  return token_name

# %%
token_name = []
for i in freq['token']:
  try:
    token_name.append(df_token[df_token['Token']==i]['Meaning'].values[0])
  except:
    token_name.append('')

# %%
freq['Meaning'] = token_name

# %%
freq
# Out:
#       token  Frequency_Documents                       Meaning
# 0        15                 6014         LENDER’S INSTRUCTIONS
# 1        14                 5180                    BUYER’S CD
# 2        28                 4230                   LENDER NOTE
# 3        30                 4120               LENDER MORTGAGE
# 4        40                 4006  LENDER AMORTIZATION SCHEDULE
# ...     ...                  ...                           ...
# 1107   1149                    1
# 1108    803                    1
# 1109    802                    1
# 1110    768                    1
# 1111   1160                    1
#
# [1112 rows x 3 columns]

# %%
freq.to_csv("/content/drive/MyDrive/Annotation Folder/Frequency_of_Documents_Lender_Token_27_March_2023.csv", index=False)

# %%
filename = 'Frequency_of_Documents_Lender_Token_27_March_2023.csv'
Folder_name = '/content/drive/MyDrive/Annotation Folder'

# %% [markdown]
# # **SEND MAIL**

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders

# Set up email parameters
email_user = "muhammadtalha1818@gmail.com"
email_password = "ikqefajjctpsmdyi"
email_send = "meet.ahmad247@gmail.com"
subject = "Documents Frequency Attachment"

body = "Documents Frequency Attachment"

# Create a multipart message object and set headers
msg = MIMEMultipart()
msg['From'] = email_user
msg['To'] = email_send
msg['Subject'] = subject

# Attach body to message
msg.attach(MIMEText(body, 'plain'))

# Open the file in bynary
attachment = open(Folder_name+'/'+filename, "rb")

# Create a base64 encoded attachment object
part = MIMEBase('application', 'octet-stream')
part.set_payload((attachment).read())
encoders.encode_base64(part)
part.add_header('Content-Disposition', "attachment; filename= %s" % filename)

# Attach the file to the message object and send the email
msg.attach(part)
text = msg.as_string()
server = smtplib.SMTP('smtp.gmail.com', 587)
server.starttls()
server.login(email_user, email_password)

server.sendmail(email_user, email_send, text)
server.quit()
print(f"S E N T to {email_send}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0ec5cfb72448> in <module>
#      23
#      24 # Open the file in bynary
# ---> 25 attachment = open(Folder_name+'/'+filename, "rb")
#      26
#      27 # Create a base64 encoded attachment object
#
# NameError: name 'Folder_name' is not defined
